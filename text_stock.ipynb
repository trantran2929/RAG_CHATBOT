# %% [markdown]
# ### **Thông tin công ty**

# %%
from vnstock import Company
company = Company(symbol='VCB', source='TCBS')

# %%
company.overview()
# Out:
#   symbol exchange industry company_type  no_shareholders  foreign_percent  \
# 0    VCB     HOSE    Banks           NH            25183            0.216
#
#    outstanding_share  issue_share established_year  no_employees  \
# 0             8355.7       8355.7             2008         24306
#
#    stock_rating  delta_in_week  delta_in_month  delta_in_year   short_name  \
# 0           2.6          0.012          -0.062          -0.29  Vietcombank
#
#                       website  industry_id industry_id_v2
# 0  https://vietcombank.com.vn          289           8355

# %%
# Cổ đông
company.shareholders()
# Out:
#                 share_holder  share_own_percent
# 0  The State Bank Of Vietnam             0.7480
# 1          Mizuho Bank, Ltd.             0.1500
# 2                      Other             0.0151

# %%
# Ban lãnh đạo 
company.officers(filter_by='working')
# Out:
#             officer_name                         officer_position  \
# 8      Nguyen Danh Luong                                Spokesman
# 11         Le Hoang Tung                                Spokesman
# 13           Le Viet Anh                                     ROOT
# 14           Le Viet Anh  Person in charge of Corporate governace
# 9       Do Thi Mai Huong              Member of Supervisors Board
# 6      Nguyen Danh Luong               Member of Management Board
# 16        Le Thi Kim Nga               Member of Management Board
# 19   Nguyen Thi Kim Oanh               Member of Management Board
# 5      Nguyen Thanh Tung                     Legal Representative
# 3   Phung Nguyen Hai Yen                  Deputy General Director
# 7      Nguyen Danh Luong                  Deputy General Director
# 10         Le Hoang Tung                  Deputy General Director
# 18       NGUYEN VAN TUAN                  Deputy General Director
# 15           Le Viet Anh                        Company Secretary
# 4      Nguyen Thanh Tung             Chairman of Management Board
# 0          Dam Lam Thanh                                     None
# 1       Dau Thi Thuy Van                                     None
# 2      Nghiem Xuan Thanh                                     None
# 12         Nguyen My Hao                                     None
# 17               Dao Hao                                     None
#
#     officer_own_percent
# 8                   0.0
# 11                  0.0
# 13                  0.0
# 14                  0.0
# 9                   0.0
# 6                   0.0
# 16                  0.0
# 19                  0.0
# 5                   0.0
# 3                   0.0
# 7                   0.0
# 10                  0.0
# 18                  0.0
# 15                  0.0
# 4                   0.0
# 0                   0.0
# 1                   0.0
# 2                   0.0
# 12                  0.0
# 17                  0.0

# %%
# Công ty con
company.subsidiaries()
# Out:
#                                      sub_company_name  sub_own_percent
# 0   Vietnam Foreign Trade Joint Stock Bank Securit...            1.000
# 1   Money Transfer Company Limited Joint Stock Com...            1.000
# 2              Vietcombank Financial Leasing Co., Ltd            1.000
# 3     Vietnam Finance Company In Hong Kong - Vinafico            1.000
# 4                                    Vietnam Neo Bank            1.000
# 5       Foreign Trade Of Vietnam Bank Limited In Laos            1.000
# 6                                   Vcb Money Company            0.875
# 7                           Vietcombank Tower 198 Ltd            0.700
# 8   Vietcombank-bonday-benthanh Joint Venture Comp...            0.520
# 9         Vietcombank Fund Management Company Limited            0.510
# 10              FWD Vietnam Insurance Company Limited            0.450
# 11                 Vietcombank-bonday Company Limited            0.160
# 12                   Petrolimex Insurance Corporation            0.080
# 13  Vietnam Export Import Commercial Joint Stock Bank            0.045
# 14               Military Commercial Joint Stock Bank            0.043
# 15               Vietnam Airlines Joint Stock Company            0.010
# 16   PetroVietNam Driling & Well Services Corporation            0.002
# 17                 Orient Commercial Joint Stock Bank            0.000

# %%
company.events().head(3)
# Out:
#     rsi    rs       id    price  price_change  price_change_ratio  \
# 0  41.8  38.0  2601159  61554.0        -595.0              -0.010
# 1  53.6  56.0  2600289  65227.0         -99.0              -0.002
# 2  66.8  56.0  2599774  67014.0       -1390.0              -0.020
#
#    price_change_ratio_1m                                         event_name  \
# 0                 -0.075  VCB - Pay cash dividend 2024 - Year at VND 450...
# 1                  0.051                               VCB - Change Address
# 2                  0.098                   VCB - Report Insider Transaction
#
#   event_code notify_date   exer_date reg_final_date exer_right_date  \
# 0        DIV  2025-09-30  2025-10-24     2025-10-06      2025-10-03
# 1       OTHE  2025-09-11  2025-09-03     1753-01-01      1753-01-01
# 2      DDINS  2025-09-05  2025-08-29     1753-01-01      1753-01-01
#
#                                           event_desc
# 0  Joint Stock Commercial Bank For Foreign Trade ...
# 1  Joint Stock Commercial Bank For Foreign Trade ...
# 2  - Name of person/ corporation that conducts th...

# %%
company.news().head(3)
# Out:
#     rsi    rs  price  price_change  price_change_ratio  price_change_ratio_1m  \
# 0  41.8  37.0  61653          -298              -0.005                 -0.073
# 1  41.8  38.0  61554          -595              -0.010                 -0.075
# 2  42.0  39.0  62546           297               0.005                 -0.009
#
#          id                                              title source  \
# 0  11728557  VCB: Nghị quyết HĐQT về việc phê duyệt chủ trư...   TCBS
# 1  11725892  VCB: Thông báo về ngày đăng ký cuối cùng trả c...   TCBS
# 2  11721351  VCB: Nghị quyết HĐQT về việc phê duyệt thanh t...   TCBS
#
#           publish_date
# 0  2025-10-02 15:33:12
# 1  2025-09-30 13:35:33
# 2  2025-09-25 14:02:12

# %%
# Báo cáo phân tích
company.reports()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[30], line 2
#       1 # Báo cáo phân tích
# ----> 2 company.reports()
#
# File c:\Users\admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\vnstock\base.py:90, in BaseAdapter.__getattr__(self, name)
#      88 def __getattr__(self, name):
#      89     # Delegate attribute access to the provider
# ---> 90     return getattr(self._provider, name)
#
# AttributeError: 'Company' object has no attribute 'reports'

# %%
# tình hình tài chính
company.ratio_summary()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[21], line 2
#       1 # tình hình tài chính
# ----> 2 company.ratio_summary()
#
# File c:\Users\admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\vnstock\base.py:90, in BaseAdapter.__getattr__(self, name)
#      88 def __getattr__(self, name):
#      89     # Delegate attribute access to the provider
# ---> 90     return getattr(self._provider, name)
#
# AttributeError: 'Company' object has no attribute 'ratio_summary'

# %%
# Thống kê giao dịch
company.trading_stats()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 2
#       1 # Thống kê giao dịch
# ----> 2 company.trading_stats()
#
# File c:\Users\admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\vnstock\base.py:90, in BaseAdapter.__getattr__(self, name)
#      88 def __getattr__(self, name):
#      89     # Delegate attribute access to the provider
# ---> 90     return getattr(self._provider, name)
#
# AttributeError: 'Company' object has no attribute 'trading_stats'

# %%
company.profile()
# Out:
#   symbol                                       company_name  \
# 0    VCB  Joint Stock Commercial Bank For Foreign Trade ...
#
#                                      company_profile  \
# 0   Joint Stock Commercial Bank For Foreign Trade...
#
#                                          history_dev company_promise  \
# 0    October 30, 1962: Bank for Foreign Trade of ...            None
#
#                                        business_risk  \
# 0   Risks related to geopolitical instability and...
#
#                                     key_developments  \
# 0    Account service Mobilizing capital service; ...
#
#                                  business_strategies
# 0      As the leading bank in Vietnam, one of the...

# %%
# Lịch sử chia cổ tức
company.dividends().head(3)
# Out:
#   exercise_date  cash_year  cash_dividend_percentage issue_method
# 0    2025-10-03       2024                     0.045         cash
# 1    2025-03-12       2025                     0.495        share
# 2    2023-07-25       2023                     0.181        share

# %%
# Giao dịch nội bộ
company.insider_deals().head(5)
# Out:
#   deal_announce_date       deal_method deal_action  deal_quantity  deal_price  \
# 0         2025-09-05       Cổ đông lớn         Bán       -58757.0     67014.0
# 1         2025-05-15    Cổ đông nội bộ         Mua        20000.0     58277.0
# 2         2025-02-20    Cổ đông nội bộ         Mua        10000.0     60896.0
# 3         2023-12-21    Cổ đông nội bộ         Mua         5000.0     53724.0
# 4         2020-12-30  Cổ đông sáng lập         Bán        -2523.0     42618.0
#
#    deal_ratio
# 0      -0.045
# 1       0.098
# 2       0.051
# 3       0.191
# 4       0.502

# %% [markdown]
# ### **Cổ phiếu:**

# %%
from vnstock import Listing
listing = Listing(source='VCI')

# %%
# Liệt kê mã CP
listing.all_symbols()
# Out:
#      symbol                                         organ_name
# 0       YTC  Công ty Cổ phần Xuất nhập khẩu Y tế Thành phố ...
# 1       YEG                     Công ty Cổ phần Tập đoàn Yeah1
# 2       YBM     Công ty Cổ phần Khoáng sản Công nghiệp Yên Bái
# 3       YBC      Công ty Cổ phần Xi măng và Khoáng sản Yên Bái
# 4       XPH                    Công ty Cổ phần Xà phòng Hà Nội
# ...     ...                                                ...
# 1714    AAS            Công ty Cổ phần Chứng khoán SmartInvest
# 1715    AAM                    Công ty Cổ Phần Thủy Sản MeKong
# 1716    AAH                           Công ty Cổ phần Hợp Nhất
# 1717    AAA                  Công ty Cổ phần Nhựa An Phát Xanh
# 1718    A32                                 Công ty Cổ phần 32
#
# [1719 rows x 2 columns]

# %%
# Liệt kê mã CP theo sàn
listing.symbols_by_exchange().head(5)
# Out:
#   symbol exchange   type               organ_short_name  \
# 0    YTC    UPCOM  STOCK                XNK Y tế TP.HCM
# 1    YEG      HSX  STOCK                 Tập đoàn Yeah1
# 2    YBM      HSX  STOCK          Khoáng sản CN Yên Bái
# 3    YBC    UPCOM  STOCK  Xi măng và Khoáng sản Yên Bái
# 4    XPH    UPCOM  STOCK                Xà phòng Hà Nội
#
#                                           organ_name product_grp_id
# 0  Công ty Cổ phần Xuất nhập khẩu Y tế Thành phố ...            UPX
# 1                     Công ty Cổ phần Tập đoàn Yeah1            STO
# 2     Công ty Cổ phần Khoáng sản Công nghiệp Yên Bái            STO
# 3      Công ty Cổ phần Xi măng và Khoáng sản Yên Bái            UPX
# 4                    Công ty Cổ phần Xà phòng Hà Nội            UPX

# %% [markdown]
# - Liệt kê tất cả mã chứng khoán theo nhóm phân loại.
#
# * HOSE, HNX, UPCOM
# * VN30, VN100, HNX30
# * VNMidCap, VNSmallCap, VNAllShare, HNXCon, HNXFin HNXLCap, HNXMSCap, HNXMan,
# * ETF
# * FU_INDEX (mã chỉ số hợp đồng tương lai)
# * CW (chứng quyền)

# %%
# Liệt kê mã CP theo phân nhóm
listing.symbols_by_group('HOSE')
# Out:
# 0      AAA
# 1      AAM
# 2      AAT
# 3      ABR
# 4      ABS
#       ...
# 408    VTB
# 409    VTO
# 410    VTP
# 411    YBM
# 412    YEG
# Name: symbol, Length: 413, dtype: object

# %%
# CP theo ngành ICB
listing.symbols_by_industries().head(3)
# Out:
#   symbol                                         organ_name  \
# 0    F88                         Công ty Cổ phần Đầu tư F88
# 1    DVT  Trung tâm Đào tạo nghiệp vụ Giao thông vận tải...
# 2    AFX  Công ty Cổ phần Xuất Nhập khẩu Nông sản Thực p...
#
#                          icb_name3                   icb_name2  \
# 0                Dịch vụ tài chính           Dịch vụ tài chính
# 1       Tư vấn & Hỗ trợ Kinh doanh  Hàng & Dịch vụ Công nghiệp
# 2  Phân phối thực phẩm & dược phẩm                      Bán lẻ
#
#              icb_name4 com_type_code icb_code1 icb_code2 icb_code3 icb_code4
# 0    Tài chính cá nhân            CT      8000      8700      8770      8773
# 1   Đào tạo & Việc làm            CT      2000      2700      2790      2793
# 2  Phân phối thực phẩm            CT      5000      5300      5330      5337

# %%
# Danh sách ngành ICB
listing.industries_icb().head(3)
# Out:
#                                  icb_name  \
# 0                        Sản xuất Dầu khí
# 1  Thiết bị, Dịch vụ và Phân phối Dầu khí
# 2                                Hóa chất
#
#                               en_icb_name icb_code  level
# 0                     Oil & Gas Producers     0530      3
# 1  Oil Equipment, Services & Distribution     0570      3
# 2                               Chemicals     1350      3

# %% [markdown]
# ### **Thống kê giá lịch sử:**

# %%
from vnstock import Quote
quote = Quote(symbol='VCI', source='VCI')

# %%
quote.history(start='2025-10-06', end='2025-10-07')
# Out:
#         time  open  high   low  close    volume
# 0 2025-10-06  42.1  44.5  42.1   44.5  10258700

# %%
# Dữ liệu khớp lệnh
quote.intraday()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\tenacity\__init__.py:480, in Retrying.__call__(self, fn, *args, **kwargs)
#     479 try:
# --> 480     result = fn(*args, **kwargs)
#     481 except BaseException:  # noqa: B902
#
# File c:\Users\admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\vnstock\base.py:27, in dynamic_method.<locals>.wrapper(self, *args, **kwargs)
#      26 filtered = {k: v for k, v in kwargs.items() if k in sig.parameters}
# ---> 27 return provider_method(*args, **filtered)
#
# File c:\Users\admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\vnai\beam\quota.py:291, in _create_wrapper.<locals>.wrapper(*args, **kwargs)
#     290 try:
# --> 291     result = func(*args, **kwargs)
#     292     success = True
#
# File c:\Users\admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\vnstock\explorer\vci\quote.py:151, in Quote.intraday(self, page_size, last_time, to_df, show_log)
#     150 if market_status['is_trading_hour'] is False and market_status['data_status'] == 'preparing':
# --> 151     raise ValueError(f"{market_status['time']}: Dữ liệu khớp lệnh không thể truy cập trong thời gian chuẩn bị phiên mới. Vui lòng quay lại sau.")
#     153 if self.symbol is None:
#
# ValueError: 07:43:32: Dữ liệu khớp lệnh không thể truy cập trong thời gian chuẩn bị phiên mới. Vui lòng quay lại sau.
#
# The above exception was the direct cause of the following exception:
#
# RetryError                                Traceback (most recent call last)
# Cell In[24], line 2
#       1 # Dữ liệu khớp lệnh
# ----> 2 quote.intraday()
#
# File c:\Users\admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\tenacity\__init__.py:338, in BaseRetrying.wraps.<locals>.wrapped_f(*args, **kw)
#     336 copy = self.copy()
#     337 wrapped_f.statistics = copy.statistics  # type: ignore[attr-defined]
# --> 338 return copy(f, *args, **kw)
#
# File c:\Users\admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\tenacity\__init__.py:477, in Retrying.__call__(self, fn, *args, **kwargs)
#     475 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     476 while True:
# --> 477     do = self.iter(retry_state=retry_state)
#     478     if isinstance(do, DoAttempt):
#     479         try:
#
# File c:\Users\admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\tenacity\__init__.py:378, in BaseRetrying.iter(self, retry_state)
#     376 result = None
#     377 for action in self.iter_state.actions:
# --> 378     result = action(retry_state)
#     379 return result
#
# File c:\Users\admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\tenacity\__init__.py:421, in BaseRetrying._post_stop_check_actions.<locals>.exc_check(rs)
#     419 if self.reraise:
#     420     raise retry_exc.reraise()
# --> 421 raise retry_exc from fut.exception()
#
# RetryError: RetryError[<Future at 0x2323f809850 state=finished raised ValueError>]

# %% [markdown]
# ### **Báo cáo tài chính**

# %%
from vnstock import Finance
finance = Finance(symbol='VCI', source='VCI') # source = TCBS

# %%
# Báo cáo kết quả kinh doanh
finance.income_statement(period='year', lang='vi')
# Out:
#      CP   Năm  Doanh thu (đồng)  Tăng trưởng doanh thu (%)  \
# 0   VCI  2024     3695525335470                   0.494675
# 1   VCI  2023     2472460543397                  -0.216644
# 2   VCI  2022     3156242736345                  -0.148588
# 3   VCI  2021     3707068724492                   1.143320
# 4   VCI  2020     1729591590563                   0.122423
# 5   VCI  2019     1540944352650                  -0.154015
# 6   VCI  2018     1821479495575                   0.185287
# 7   VCI  2017     1536741663856                   0.719618
# 8   VCI  2016      893653059787                   0.275369
# 9   VCI  2015      700701338901                   0.136233
# 10  VCI  2014      616688248624                   0.543810
# 11  VCI  2013      399458747857                  -0.138641
# 12  VCI  2011      463753810568                   0.000000
#
#     Lợi nhuận sau thuế của Cổ đông công ty mẹ (đồng)  \
# 0                                       910692113293
# 1                                       491904659394
# 2                                       868978185802
# 3                                      1498718375328
# 4                                       768912289421
# 5                                       693180577268
# 6                                       834621627351
# 7                                       655096164914
# 8                                       335051546171
# 9                                       237198169547
# 10                                      145272769307
# 11                                       72169919104
# 12                                       24966553737
#
#     Tăng trưởng lợi nhuận (%)  Doanh thu thuần  Giá vốn hàng bán  \
# 0                    0.851359    3695525335470    -1717402022529
# 1                   -0.433927    2472460543397    -1063597101525
# 2                   -0.420186    3156242736345    -1398531179478
# 3                    0.949141    3707068724492    -1326133822522
# 4                    0.109253    1729591590563     -522004485232
# 5                   -0.169467    1540944352650     -462563219754
# 6                    0.274044    1821479495575     -470178300230
# 7                    0.955210    1536741663856     -442507882892
# 8                    0.412538     893653059787     -262284220644
# 9                    0.632778     700701338901     -213881837970
# 10                   1.012927     616688248624     -364160278791
# 11                   1.890664     399458747857     -262556133881
# 12                   0.000000     463753810568     -391934027821
#
#           Lãi gộp  Thu nhập tài chính  ...  Lợi nhuận khác  LN trước thuế  \
# 0   1978123312941        5.063321e+10  ...      2785303975  1089337104906
# 1   1408863441872        2.369615e+10  ...       128411319   570138640134
# 2   1757711556867        3.554843e+10  ...     43696276107  1059738713385
# 3   2380934901970        2.561687e+10  ...      -267786912  1850585393088
# 4   1207587105331        5.858556e+09  ...       621078878   951038957081
# 5   1078381132896        9.926627e+09  ...        17597948   855007109256
# 6   1351301195345        8.024256e+09  ...      8384183106  1023455908924
# 7   1094233780964        6.271435e+09  ...     11061826696   802977679615
# 8    631368839143        5.398922e+09  ...         6680537   415888536017
# 9    486819500931        5.025766e+09  ...      -288835880   300960284712
# 10   252527969833        0.000000e+00  ...      -684811399   182828859179
# 11   136902613976        0.000000e+00  ...        82429268    90203867489
# 12    71819782747        0.000000e+00  ...        33325000    32501527420
#
#     Chi phí thuế TNDN hiện hành  Chi phí thuế TNDN hoãn lại  Lợi nhuận thuần  \
# 0                 -178605980097                   -39011516     910692113293
# 1                  -64320454739                -13913526001     491904659394
# 2                 -250981079495                 60220551912     868978185802
# 3                 -309748513618                -42118504142    1498718375328
# 4                 -182422798514                   296130854     768912289421
# 5                 -155223164412                 -6603367576     693180577268
# 6                 -192707433489                  3873151916     834621627351
# 7                 -128693085155                -19188429546     655096164914
# 8                  -79615329710                  1237400094     337510606401
# 9                  -58822446462                 -3038958111     239098880139
# 10                 -35247540841                 -2308549031     145272769307
# 11                 -23010188596                  4976240211      72169919104
# 12                  -7534973683                           0      24966553737
#
#     Cổ đông thiểu số  Cổ đông của Công ty mẹ  \
# 0                  0            910692113293
# 1                  0            491904659394
# 2                  0            868978185802
# 3                  0           1498718375328
# 4                  0            768912289421
# 5                  0            693180577268
# 6                  0            834621627351
# 7                  0            655096164914
# 8         2459060230            335051546171
# 9         1900710592            237198169547
# 10                 0            145272769307
# 11                 0             72169919104
# 12                 0             24966553737
#
#     Doanh thu bán hàng và cung cấp dịch vụ  Thu nhập khác  \
# 0                            3695525335470     3094145678
# 1                            2472460543397      132390105
# 2                            3156242736345    44543029091
# 3                            3707068724492       69316632
# 4                            1729591590563      621078878
# 5                            1540944352650       17597948
# 6                            1821479495575     8554303031
# 7                            1536741663856    11119139864
# 8                             893653059787      299775092
# 9                             700701338901      104529819
# 10                            616688248624     -644037102
# 11                            399458747857       98681819
# 12                            463753810568       33325000
#
#     Thu nhập/Chi phí khác
# 0              -308841703
# 1                -3978786
# 2              -846752984
# 3              -337103544
# 4                       0
# 5                       0
# 6              -170119925
# 7               -57313168
# 8              -293094555
# 9              -393365699
# 10               40774297
# 11              -16252551
# 12                      0
#
# [13 rows x 24 columns]

# %%
# Bảng cân đối kế toán
finance.balance_sheet(period='year', lang='vi')
# Out:
#      CP   Năm  TÀI SẢN NGẮN HẠN (đồng)  Tiền và tương đương tiền (đồng)  \
# 0   VCI  2024           26491835561026                    4743771932745
# 1   VCI  2023           17174448616966                     787897819240
# 2   VCI  2022           14157693071824                    3423501614803
# 3   VCI  2021           16568965942558                    1131748599533
# 4   VCI  2020            8312170798945                     642512983590
# 5   VCI  2019            7173102515011                     794511762602
# 6   VCI  2018            6430493843962                    1144361568890
# 7   VCI  2017            6342806740944                     486703202803
# 8   VCI  2016            3075625891871                     545670784533
# 9   VCI  2015            2423478575254                     158181741192
# 10  VCI  2014            2707101348631                     618777857754
# 11  VCI  2013            2090711345801                     312645301464
# 12  VCI  2011            1795452129469                     111616718751
#
#     Giá trị thuần đầu tư ngắn hạn (đồng)  Các khoản phải thu ngắn hạn (đồng)  \
# 0                         21072524575199                        506858248065
# 1                         15097165308797                       1094491429414
# 2                         10562264962864                        120085485886
# 3                         14998113044339                        285206345277
# 4                          6697916243107                        221798617565
# 5                          5817229478552                        747087592357
# 6                          5252959790479                         30487868695
# 7                          5709256554482                         28256236703
# 8                          2481417250820                         44869461531
# 9                          2092718191471                         78849205458
# 10                         1939716412996                        141064801745
# 11                         1659030664666                        117641213076
# 12                         1059922610501                        614818783909
#
#     Hàng tồn kho ròng  Tài sản lưu động khác  TÀI SẢN DÀI HẠN (đồng)  \
# 0                   0           168680805017            100288918214
# 1                   0           194894059515             80686039559
# 2                   0            51841008271             85058244998
# 3                   0           153897953409             67299004559
# 4                   0            97527648804             70234326495
# 5                   0           165433739031             69857713462
# 6                   0             2684615898             79502079245
# 7                   0           118590746956             59205004260
# 8                   0             7607339062             34921874969
# 9                   0            92517941380             39867670505
# 10           14179400             7528096736             63219168401
# 11           16677400             1377489195             41576018914
# 12           12320284             9081696024            622201775573
#
#     Tài sản cố định (đồng)  ...  Hàng tồn kho, ròng (đồng)  \
# 0              37268698440  ...                          0
# 1              23425609453  ...                          0
# 2              23496558588  ...                          0
# 3              13155825424  ...                          0
# 4              14384201512  ...                          0
# 5               9907318916  ...                          0
# 6              18226354386  ...                          0
# 7              25326131092  ...                          0
# 8               9489824544  ...                          0
# 9              14899441202  ...                          0
# 10             18390029859  ...                   14179400
# 11             11027268785  ...                   16677400
# 12              7612776214  ...                   12320284
#
#     Tài sản lưu động khác (đồng)  Cổ phiếu phổ thông (đồng)  \
# 0                   135374861200               7.180995e+12
# 1                   147257185100               4.375000e+12
# 2                    46136989800               4.354999e+12
# 3                   150714917648               3.330000e+12
# 4                    91333803000               1.656000e+12
# 5                   164204396000               1.644000e+12
# 6                              0               1.629999e+12
# 7                   116156411000               1.200000e+12
# 8                     1335936000               1.032000e+12
# 9                    87885991500               5.000000e+11
# 10                    3095401526               5.000000e+11
# 11                      87777500               0.000000e+00
# 12                    6609715987               3.780000e+11
#
#     Vốn góp của chủ sở hữu (đồng)  Vay và nợ thuê tài chính dài hạn (đồng)  \
# 0                   7180994800000                                        0
# 1                   4375000000000                                        0
# 2                   4354999010000                                        0
# 3                   3330000000000                                        0
# 4                   1656000000000                                        0
# 5                   1644000000000                                        0
# 6                   1629998900000                                        0
# 7                   1200000000000                                        0
# 8                   1032000000000                                        0
# 9                    500000000000                                        0
# 10                   500000000000                                        0
# 11                   398400000000                                        0
# 12                   378000000000                             500000000000
#
#     Người mua trả tiền trước ngắn hạn (đồng)  \
# 0                                 2743133560
# 1                                  378319774
# 2                                  221000000
# 3                                52551076244
# 4                                 7971369863
# 5                                  210000000
# 6                               126324890101
# 7                               462392057000
# 8                               571264678998
# 9                               799974087998
# 10                              840646942003
# 11                              470366997300
# 12                              121749992655
#
#     Vay và nợ thuê tài chính ngắn hạn (đồng)  Trả trước dài hạn (đồng)  \
# 0                             12573864000000                6238956911
# 1                              8979275000000                7943878800
# 2                              6326207142857               13290531600
# 3                              6362680000000               10702485700
# 4                              2696130000000               12950546970
# 5                              1450980000000               17085900679
# 6                               984860000000               25494063880
# 7                              1434460418662                2171535344
# 8                               627508000000                4433448206
# 9                               535500000000                9817929938
# 10                              266511750000               14560154043
# 11                              648400000000               16231644217
# 12                              582426780000                         0
#
#     Tài sản dài hạn khác (đồng)  LỢI ÍCH CỦA CỔ ĐÔNG THIỂU SỐ
# 0                             0                  0.000000e+00
# 1                             0                  0.000000e+00
# 2                             0                  0.000000e+00
# 3                             0                  0.000000e+00
# 4                             0                  0.000000e+00
# 5                             0                  0.000000e+00
# 6                             0                  0.000000e+00
# 7                             0                  0.000000e+00
# 8                             0                  7.721605e+10
# 9                             0                  7.475699e+10
# 10                  14160000000                  7.604128e+10
# 11                            0                  0.000000e+00
# 12                 594640525000                  0.000000e+00
#
# [13 rows x 32 columns]

# %%
# báo cáo lưu chuyển tiền tệ
finance.cash_flow(period='year', lang='vi')
# Out:
#      CP   Năm  Lãi/Lỗ ròng trước thuế  Khấu hao TSCĐ  Dự phòng RR tín dụng  \
# 0   VCI  2024           1089337104906    10751194638            4516800000
# 1   VCI  2023            570138640134     9679599271           11292000000
# 2   VCI  2022           1059738713385     9647191174                     0
# 3   VCI  2021           1850585393088     7496942452            -214202387
# 4   VCI  2020            951038957081    10634646105             -35400000
# 5   VCI  2019            855007109256    11729076470              22200000
# 6   VCI  2018           1011455908924    11577959706          -19945610083
# 7   VCI  2017            802977679615     9773790332          -15149537030
# 8   VCI  2016            415888536017     8060391011           22916148519
# 9   VCI  2015            300960284712     9770470117          -12721010619
# 10  VCI  2014            182828859179     6970993921          -45635182260
# 11  VCI  2013             90203867489     5086901992            3964813528
# 12  VCI  2011             32501527420     8007836758          109075662980
#
#     Lãi/Lỗ chênh lệch tỷ giá chưa thực hiện  Lãi/Lỗ từ hoạt động đầu tư  \
# 0                                         0                           0
# 1                                         0                           0
# 2                                         0                   154602984
# 3                                         0                           0
# 4                                         0                  -500000000
# 5                                         0                    -8900000
# 6                                         0                    -4000000
# 7                                         0                   -13636364
# 8                                         0                           0
# 9                                 -72727273                           0
# 10                                        0                -24666019387
# 11                                        0                -30835493998
# 12                                        0               -237535351496
#
#     Thu nhập lãi  Thu lãi và cổ tức  \
# 0   764124674808      -8.608679e+10
# 1   562553033255      -1.032191e+11
# 2   477360036322      -5.948490e+10
# 3   330776772616      -4.785212e+10
# 4   173513458172      -2.094800e+10
# 5   165277553123      -4.476748e+10
# 6   250502717563      -2.712690e+10
# 7   179160956958      -1.077056e+09
# 8   132700817124      -3.288771e+09
# 9   104736709961      -1.047686e+10
# 10   68648275576       0.000000e+00
# 11   60220273878       0.000000e+00
# 12  135442068650       0.000000e+00
#
#     Lưu chuyển tiền thuần từ HĐKD trước thay đổi VLĐ  ...  \
# 0                                     -5169139240487  ...
# 1                                     -5407321967895  ...
# 2                                      2006811362129  ...
# 3                                     -5732733292320  ...
# 4                                     -1673271187005  ...
# 5                                     -1299721219619  ...
# 6                                      -518725282730  ...
# 7                                     -2831415493901  ...
# 8                                      -708274377223  ...
# 9                                      -782555925965  ...
# 10                                      188561924385  ...
# 11                                      128640362889  ...
# 12                                       47491744312  ...
#
#     Chi trả cho việc mua lại, trả cổ phiếu  Tiền thu được các khoản đi vay  \
# 0                                        0                  28212221000000
# 1                                        0                  20322010000000
# 2                                        0                  15126047142857
# 3                                        0                  16591566600000
# 4                               -852000000                   7065840000000
# 5                              -1000592110                   4997872000000
# 6                               -292500000                   7499020870841
# 7                                -60000000                   5317822218662
# 8                                        0                   2896208000000
# 9                                        0                   3264500000000
# 10                                       0                   2225261750000
# 11                                       0                   2468260000000
# 12                                       0                   1944102280000
#
#     Tiền trả các khoản đi vay  Cổ tức đã trả  \
# 0             -24737632000000  -177803580300
# 1             -18096042142857  -522119971000
# 2             -16579490000000              0
# 3             -11629266600000  -730123222800
# 4              -6233940000000  -411641446500
# 5              -4785602000000  -227957358660
# 6              -7519451289503  -119754016000
# 7              -4071119800000   -62216391100
# 8              -2337700000000   -78818064000
# 9              -2995511750000   -72821786200
# 10             -2607150000000   -59543768000
# 11             -2618860000000   -31664908000
# 12             -1143737300000   -18686750000
#
#     Lưu chuyển tiền từ hoạt động tài chính  Lưu chuyển tiền thuần trong kỳ  \
# 0                            7371225419700                   3955874113505
# 1                            1727849074143                  -2635603795563
# 2                           -1428442857143                   2291753015270
# 3                            4245676777200                    489235615943
# 4                             432858721500                   -151998779012
# 5                                113369230                   -349849806288
# 6                            -120006934662                    657658366087
# 7                            1924826027562                    -37159908808
# 8                             524689936000                    387489043341
# 9                             196166463800                   -226360484928
# 10                           -339832018000                    306132556290
# 11                           -182264908000                    -71536737881
# 12                            781678230000                     11262150545
#
#     Tiền và tương đương tiền  Tiền và tương đương tiền cuối kỳ  \
# 0               787897819240                     4743771932745
# 1              3423501614803                      787897819240
# 2              1131748599533                     3423501614803
# 3               642512983590                     1131748599533
# 4               794511762602                      642512983590
# 5              1144361568890                      794511762602
# 6               486703202803                     1144361568890
# 7               523863111611                      486703202803
# 8               158181741192                      545670784533
# 9               384542226120                      158181741192
# 10              312645301464                      618777857754
# 11              384182039345                      312645301464
# 12              100354568206                      111616718751
#
#     _Tăng/Giảm các khoản phải thu  _Tăng/Giảm các khoản phải trả
# 0                               0                    65609975849
# 1                               0                     3923102445
# 2                               0                  -119194100124
# 3                      5939376000                    88803338332
# 4                     57321090000                  -265045502541
# 5                    -63260466000                   129318994530
# 6                       172500000                  -428668687229
# 7                      -172500000                   -11448928624
# 8                      -990827917                  -364304572256
# 9                       -12952691                  -618496706072
# 10                  -135946093494                   738303431370
# 11                   111903229855                   -64166575943
# 12                   148895236278                  -198500464373
#
# [13 rows x 38 columns]

# %%
# Chỉ số tài chính
finance.ratio(period='year', lang='vi')
# Out:
#    Meta          Chỉ tiêu cơ cấu nguồn vốn                           \
#      CP   Năm Kỳ          (Vay NH+DH)/VCSH   Nợ/VCSH TSCĐ / Vốn CSH
# 0   VCI  2024  5                  0.971382  1.054349       0.002879
# 1   VCI  2023  5                  1.218152  1.340876       0.003178
# 2   VCI  2022  5                  0.973942  1.192721       0.003617
# 3   VCI  2021  5                  0.972610  1.543047       0.002011
# 4   VCI  2020  5                  0.596293  0.853905       0.003181
# 5   VCI  2019  5                  0.358125  0.787676       0.002445
# 6   VCI  2018  5                  0.270345  0.786999       0.005003
# 7   VCI  2017  5                  0.475082  1.120296       0.008388
# 8   VCI  2016  5                  0.491563  1.436668       0.007434
# 9   VCI  2015  5                  0.550475  1.532230       0.015316
# 10  VCI  2014  5                  0.364664  2.686542       0.022791
# 11  VCI  2013  5                  1.191585  2.918571       0.020265
# 12  VCI  2011  5                  3.426721  4.235392       0.016485
#
#                        Chỉ tiêu hiệu quả hoạt động                 \
#    Vốn CSH/Vốn điều lệ           Vòng quay tài sản Vòng quay TSCĐ
# 0             1.791351                    0.168564     121.775022
# 1             1.020098                    0.156992     105.385605
# 2             0.898902                    0.204426     172.225781
# 3             0.905323                    0.296344     269.213152
# 4             0.625725                    0.221383     142.402909
# 5             0.560698                    0.224089     109.544483
# 6             0.504149                    0.282137      83.645260
# 7             0.417852                    0.323097      88.278011
# 8             0.176662                    0.320657      73.282490
# 9             0.134625                    0.267767      41.241080
# 10            0.111664                    0.251576      40.964295
# 11            0.075304                    0.180038      30.100257
# 12            0.063907                    0.221780      45.438230
#
#                                ... Chỉ tiêu thanh khoản Chỉ tiêu định giá  \
#    Số ngày thu tiền bình quân  ...    Đòn bẩy tài chính               P/B
# 0                    0.000000  ...             2.054349          2.468686
# 1                    0.000000  ...             2.340876          1.970499
# 2                    0.000000  ...             2.192721          2.866248
# 3                    0.000000  ...             2.543047          1.183493
# 4                    0.000000  ...             1.853905          2.666309
# 5                    0.000000  ...             1.787676          2.418360
# 6                    0.000000  ...             1.786999          2.666718
# 7                    0.000000  ...             2.120296          2.368686
# 8                    0.000000  ...             2.436668          5.128414
# 9                   21.294522  ...             2.532230          3.318337
# 10                  31.374424  ...             3.433360          4.077489
# 11                 149.353356  ...             3.918571          4.363627
# 12                 328.174272  ...             5.235392          4.878577
#
#                                                                      \
#    Vốn hóa (Tỷ đồng) Số CP lưu hành (Triệu CP)        P/E       P/S
# 0     31955426860000                 718099480  35.089166  8.647059
# 1     14525000000000                 437500000  29.528080  5.874715
# 2     18617620767750                 435499901  21.424727  5.898666
# 3      7742250000000                 333000000   5.165914  2.088510
# 4     12055680000000                 165600000  15.678875  6.970247
# 5      9798240000000                 164400000  14.135191  6.358594
# 6      9714793444000                 162999890  11.639758  5.333463
# 7      7152000000000                 120000000  10.917481  4.654003
# 8      6150720000000                 103200000  18.357534  6.882671
# 9      2980000000000                  50000000  12.563335  4.252882
# 10     2980000000000                  50000000  20.513135  4.832263
# 11     2374464000000                  39840000  32.901021  5.944203
# 12     2252880000000                  37800000  90.235922  4.857922
#
#
#    P/Cash Flow    EPS (VND)    BVPS (VND)  EV/EBITDA
# 0    -9.442956  1268.197706  18025.783068  21.573628
# 1    -3.334822  1124.353507  16848.524590  17.525975
# 2     4.975461  1995.357941  14914.970490  12.729467
# 3    -2.064593  4500.655782  19645.234971   5.895364
# 4   -21.093469  4643.190154  27303.662559  12.313747
# 5   -28.722550  4216.426869  24644.804444  10.220559
# 6    12.398987  5120.381537  22349.571713   7.529021
# 7    -3.614195  5459.134708  25161.626644   8.311031
# 8   -46.597333  3246.623509  11621.527734  11.306346
# 9    -7.172009  4743.963391  17960.802319   8.174017
# 10    4.521565  2905.455386  14616.838928  14.166357
# 11   28.472663  1811.493953  13658.362879  28.466190
# 12  -22.732493   660.490840  12216.677603  79.644405
#
# [13 rows x 37 columns]

# %% [markdown]
# ### Xuất dữ liệu thô:

# %%
# Khởi tạo class
from vnstock.explorer.vci import Finance
fin = Finance(symbol='PLX', period='quarter')

# %%
# Truy xuất báo cáo thô
fin._get_report(mode='raw').head()
# Out:
#   ticker  yearReport  lengthReport     updateDate         revenue  \
# 0    PLX        2025             2  1756803601543  76568084039970
# 1    PLX        2025             1  1746177217067  67890171339647
# 2    PLX        2024             4  1743680658300  71055339774054
# 3    PLX        2024             3  1730314778847  64352149009035
# 4    PLX        2024             2  1725440401193  73584636922071
#
#    revenueGrowth      netProfit  netProfitGrowth  ebitMargin       roe  ...  \
# 0       0.040544  1366405037475         0.133304    0.018088  0.082241  ...
# 1      -0.096387   133414809920        -0.875659    0.001401  0.075706  ...
# 2       0.034548   545272943919        -0.149400    0.006667  0.111227  ...
# 3      -0.111638    65874458258        -0.910760   -0.002339  0.115055  ...
# 4       0.118727  1205682247740         0.482842    0.016810  0.141182  ...
#
#    ISI97         CFA30          CFA2  CFB80         CFA38         CFA32  \
# 0    0.0  9.892070e+12  5.764672e+11    0.0  1.077064e+13 -1.620870e+12
# 1    0.0 -1.693769e+13  5.095880e+11    0.0  1.044673e+13 -1.007950e+07
# 2    0.0 -1.142180e+13  6.737836e+11    0.0  1.493307e+13 -2.029978e+11
# 3    0.0 -2.258806e+13  4.518609e+11    0.0  1.229352e+13  1.462638e+11
# 4    0.0 -1.463131e+13  5.395484e+11    0.0  1.555723e+13 -2.050684e+12
#
#             ISA5          BSA49  CFB64             __typename
# 0  5148108011024  3480171986189    0.0  CompanyFinancialRatio
# 1  3711902414777  3308339559036    0.0  CompanyFinancialRatio
# 2  4639794814469  3339510809214    0.0  CompanyFinancialRatio
# 3  3436435356349  3023441914208    0.0  CompanyFinancialRatio
# 4  4605641419515  2928188925989    0.0  CompanyFinancialRatio
#
# [5 rows x 213 columns]

# %%
# Truy xuất bảng tra cứu thuật ngữ 
fin._get_ratio_dict()
# Out:
#               field_name                           name  \
# 0                   BSA1          TỔNG TÀI SẢN NGẮN HẠN
# 1                   BSA2       Tiền và tương đương tiền
# 2                   BSA5  Giá trị thuần đầu tư ngắn hạn
# 3                   BSA8             Các khoản phải thu
# 4                  BSA15              Hàng tồn kho ròng
# ..                   ...                            ...
# 733                 ebit                 EBIT (Tỷ đồng)
# 734             dividend             Tỷ suất cổ tức (%)
# 735                RTQ17         Vòng quay hàng tồn kho
# 736                  fae                 TSCĐ / Vốn CSH
# 737  charterCapitalRatio            Vốn CSH/Vốn điều lệ
#
#                             en_name                         type order   unit  \
# 0                    CURRENT ASSETS     Chỉ tiêu cân đối kế toán    12     tỷ
# 1         Cash and cash equivalents     Chỉ tiêu cân đối kế toán    13     tỷ
# 2         Net Short-term investment     Chỉ tiêu cân đối kế toán    14     tỷ
# 3              Accounts Receivables     Chỉ tiêu cân đối kế toán    15     tỷ
# 4                   Net Inventories     Chỉ tiêu cân đối kế toán    16     tỷ
# ..                              ...                          ...   ...    ...
# 733                  EBIT (Bn. VND)   Chỉ tiêu khả năng sinh lợi     6     tỷ
# 734              Dividend yield (%)   Chỉ tiêu khả năng sinh lợi    13      %
# 735              Inventory Turnover  Chỉ tiêu hiệu quả hoạt động    28  index
# 736           Fixed Asset-To-Equity    Chỉ tiêu cơ cấu nguồn vốn    36  index
# 737  Owners' Equity/Charter Capital    Chỉ tiêu cơ cấu nguồn vốn    38  index
#
#     com_type_code
# 0              BH
# 1              BH
# 2              BH
# 3              BH
# 4              BH
# ..            ...
# 733            NH
# 734            NH
# 735            NH
# 736            NH
# 737            NH
#
# [738 rows x 7 columns]

# %% [markdown]
# ### **Bảng giá giao dịch**

# %%
from vnstock import Trading
trading = Trading()
trading.price_board(symbols_list=['VCB','ACB','TCB','BID'])
# Out:
#   listing                                                                  \
#    symbol ceiling  floor ref_price stock_type exchange     trading_status
# 0     VCB   66000  57400     61700      STOCK      HSX  TRADING_ACTIVATED
# 1     ACB   27400  23900     25650      STOCK      HSX  TRADING_ACTIVATED
# 2     TCB   41000  35700     38350      STOCK      HSX  TRADING_ACTIVATED
# 3     BID   42550  37050     39800      STOCK      HSX  TRADING_ACTIVATED
#
#                                                             ...     match  \
#   trading_status_code trading_status_group security_status  ... bid_count
# 0                  20                    2               N  ...         0
# 1                  20                    2               N  ...         0
# 2                  20                    2               N  ...         0
# 3                  20                    2               N  ...         0
#
#                                                                           \
#   ask_count underlying open_interest stock_type partition is_match_price
# 0         0       None          None      STOCK         4          False
# 1         0       None          None      STOCK         4          False
# 2         0       None          None      STOCK         0          False
# 3         0       None          None      STOCK         3          False
#
#
#   ceiling_price floor_price reference_price
# 0         66000       57400           61700
# 1         27400       23900           25650
# 2         41000       35700           38350
# 3         42550       37050           39800
#
# [4 rows x 57 columns]

# %%
trading.price_board(symbols_list=['VCB','ACB','TCB','BID']).iloc[0].T
# Out:
# listing  symbol                                                                      VCB
#          ceiling                                                                   66000
#          floor                                                                     57400
#          ref_price                                                                 61700
#          stock_type                                                                STOCK
#          exchange                                                                    HSX
#          trading_status                                                TRADING_ACTIVATED
#          trading_status_code                                                          20
#          trading_status_group                                                          2
#          security_status                                                               N
#          last_trading_date                                                          None
#          issue_date                                                                 None
#          listed_share                                                         8355675094
#          coupon_rate                                                                   0
#          yield                                                                         0
#          sending_time                                              20251006 01:44:21.890
#          type                                                                      STOCK
#          organ_name                    Ngân hàng Thương mại Cổ phần Ngoại thương Việt...
#          mapping_symbol                                                             None
#          product_grp_id                                                              STO
#          partition                                                                     2
#          index_type                                                                 None
#          trading_date                                                         2025-10-06
#          average_match_volume2_week                                              3890931
# bid_ask  bid_count                                                                     0
#          ask_count                                                                     0
# match    accumulated_value                                                             0
#          accumulated_volume                                                            0
#          accumulated_value_g1                                                          0
#          accumulated_volume_g1                                                         0
#          avg_match_price                                                               0
#          current_room                                                          702373672
#          foreign_buy_volume                                                            0
#          foreign_sell_volume                                                           0
#          foreign_buy_value                                                   52893762800
#          foreign_sell_value                                                  90271674200
#          highest                                                                       0
#          lowest                                                                        0
#          match_price                                                                   0
#          open_price                                                                 None
#          first_time_match_price                                                     None
#          match_type                                                                    b
#          match_vol                                                                     0
#          sending_time                                              20251006 07:45:05.230
#          total_room                                                           2506702528
#          total_buy_orders                                                              0
#          total_sell_orders                                                             0
#          bid_count                                                                     0
#          ask_count                                                                     0
#          underlying                                                                 None
#          open_interest                                                              None
#          stock_type                                                                STOCK
#          partition                                                                     4
#          is_match_price                                                            False
#          ceiling_price                                                             66000
#          floor_price                                                               57400
#          reference_price                                                           61700
# Name: 0, dtype: object

# %% [markdown]
# ### **Bộ lọc cổ phiếu**

# %%
from vnstock import Screener
screener_df = Screener().stock(params={"exchangeName": "HOSE,HNX,UPCOM"}, limit=1700)

# %%
screener_df.head()
# Out:
#   ticker exchange                 industry  market_cap  roe  stock_rating  \
# 0    A32    UPCOM  Hàng cá nhân & Gia dụng         NaN  NaN           NaN
# 1    AAA      HSX                 Hóa chất      3272.0  5.1           2.6
# 2    AAH    UPCOM        Tài nguyên Cơ bản       472.0  1.9           2.5
# 3    AAM      HSX     Thực phẩm và đồ uống        74.0 -0.1           NaN
# 4    AAS    UPCOM        Dịch vụ tài chính      2596.0  2.6           2.4
#
#    business_operation  business_model  financial_health  alpha  ...  \
# 0                 1.7             3.5               2.6    0.1  ...
# 1                 1.5             3.0               4.0   -0.1  ...
# 2                 1.1             NaN               4.4    0.0  ...
# 3                 1.1             NaN               4.2    0.0  ...
# 4                 3.8             2.8               3.2    0.2  ...
#
#    peg_forward  roa  npl  nim  \
# 0          NaN  NaN  NaN  NaN
# 1         -0.4  2.3  NaN  NaN
# 2          NaN  1.6  NaN  NaN
# 3          NaN -0.1  NaN  NaN
# 4          0.0  1.6  NaN  NaN
#
#                                      price_vs_sma200  eps_recently  \
# 0  {'vi': 'Giá cắt lên SMA(200)', 'en': 'Price cr...           NaN
# 1                                               None         698.0
# 2                                               None         192.0
# 3  {'vi': 'Giá cắt lên SMA(200)', 'en': 'Price cr...         -26.0
# 4                                               None         285.0
#
#    percent_price_vs_ma200  percent_price_vs_ma20  percent_price_vs_ma50  \
# 0                     0.0                    2.0                    0.7
# 1                     6.2                    1.4                    0.5
# 2                    -4.2                   -3.0                   -4.7
# 3                     0.4                   -0.8                   -1.9
# 4                    18.2                   -3.5                  -15.8
#
#    percent_price_vs_ma100
# 0                    -1.1
# 1                     6.7
# 2                    -3.8
# 3                    -0.6
# 4                     1.6
#
# [5 rows x 99 columns]

# %% [markdown]
# ### **Dữ liệu quỹ mở**

# %%
from vnstock import Fund
fund = Fund()
# Out:
# 2025-10-07 07:44:20 - vnstock.explorer.fmarket.fund - INFO - Total number of funds currently listed on Fmarket: 58

# %%
# Liệt kê quỹ
fund.listing().head(5)
# Out:
# 2025-10-07 07:44:23 - vnstock.explorer.fmarket.fund - INFO - Total number of funds currently listed on Fmarket: 58
#   short_name                                               name     fund_type  \
# 0       DCDS                QUỸ ĐẦU TƯ CHỨNG KHOÁN NĂNG ĐỘNG DC  Quỹ cổ phiếu
# 1      BVFED             QUỸ ĐẦU TƯ CỔ PHIẾU NĂNG ĐỘNG BẢO VIỆT  Quỹ cổ phiếu
# 2     SSISCA         QUỸ ĐẦU TƯ LỢI THẾ CẠNH TRANH BỀN VỮNG SSI  Quỹ cổ phiếu
# 3       MBVF                      QUỸ ĐẦU TƯ GIÁ TRỊ MB CAPITAL  Quỹ cổ phiếu
# 4      MAGEF  QUỸ ĐẦU TƯ CỔ PHIẾU TĂNG TRƯỞNG MIRAE ASSET VI...  Quỹ cổ phiếu
#
#                                      fund_owner_name  management_fee  \
# 0  CÔNG TY CỔ PHẦN QUẢN LÝ QUỸ DRAGON CAPITAL VIỆ...            1.95
# 1                  CÔNG TY TNHH QUẢN LÝ QUỸ BẢO VIỆT            1.00
# 2                       CÔNG TY TNHH QUẢN LÝ QUỸ SSI            1.75
# 3              CÔNG TY CỔ PHẦN QUẢN LÝ QUỸ ĐẦU TƯ MB            1.50
# 4      CÔNG TY TNHH QUẢN LÝ QUỸ MIREA ASSET VIỆT NAM            1.75
#
#   inception_date        nav  nav_change_previous  nav_change_last_year  \
# 0     2004-05-19  105123.62                -0.94                 28.80
# 1     2014-01-07   31039.00                -0.61                 35.71
# 2     2014-09-25   45383.92                -1.22                 11.27
# 3     2014-04-24   27417.00                -0.45                 23.31
# 4     2019-07-22   21238.94                -0.76                 24.58
#
#    nav_change_inception  ...  nav_change_3m  nav_change_6m  nav_change_12m  \
# 0                273.48  ...          17.35          40.04           31.39
# 1                175.78  ...          23.12          40.56           34.42
# 2                214.90  ...           9.81          20.28           14.14
# 3                 91.90  ...          11.08          26.78           25.01
# 4                112.39  ...          20.88          35.55           24.55
#
#    nav_change_24m  nav_change_36m  nav_change_36m_annualized  nav_update_at  \
# 0           67.36           98.57                      25.69     2025-10-06
# 1           61.76           81.77                      22.04     2025-10-06
# 2           50.72           79.80                      21.60     2025-10-06
# 3           52.88           73.66                      20.20     2025-10-06
# 4           55.15           70.82                      19.54     2025-10-06
#
#   fund_id_fmarket  fund_code  vsd_fee_id
# 0              28     VFMVF1  VFMVF1N001
# 1              12      BVFED   BVFEDN001
# 2              11     SSISCA  SSISCAN001
# 3              47       MBVF    MBVFN001
# 4              35      MAGEF   MAGEFN001
#
# [5 rows x 21 columns]

# %%
# Tìm kiếm quỹ
fund.filter('DC')
# Out:
#    id shortName
# 0  40     VNDCF
# 1  67      DCIP
# 2  62    HDBOND
# 3  27      DCBF
# 4  25      DCDE
# 5  28      DCDS
# 6  29      DCAF

# %%
# Báo cáo tăng trưởng NAV
fund.details.nav_report('SSISCA')
# Out:
# 2025-10-07 07:44:29 - vnstock.explorer.fmarket.fund - INFO - Retrieving data for SSISCA
#             date  nav_per_unit short_name
# 0     2017-01-04      14412.31     SSISCA
# 1     2017-01-11      14527.86     SSISCA
# 2     2017-01-18      14240.04     SSISCA
# 3     2017-01-25      14547.21     SSISCA
# 4     2017-01-31      14541.96     SSISCA
# ...          ...           ...        ...
# 1845  2025-09-30      46407.07     SSISCA
# 1846  2025-10-01      46048.41     SSISCA
# 1847  2025-10-02      46298.90     SSISCA
# 1848  2025-10-03      45944.84     SSISCA
# 1849  2025-10-06      45383.92     SSISCA
#
# [1850 rows x 3 columns]

# %%
# Danh mục đầu tư lớn
fund.details.top_holding('SSISCA')
# Out:
# 2025-10-07 07:44:33 - vnstock.explorer.fmarket.fund - INFO - Retrieving data for SSISCA
#   stock_code           industry  net_asset_percent type_asset   update_at  \
# 0        MBB          Ngân hàng               9.05      STOCK  2025-09-09
# 1        CTG          Ngân hàng               7.35      STOCK  2025-09-09
# 2        TCB          Ngân hàng               7.23      STOCK  2025-09-09
# 3        MWG             Bán lẻ               6.32      STOCK  2025-09-09
# 4        HPG  Vật liệu xây dựng               6.19      STOCK  2025-09-09
# 5        VCB          Ngân hàng               4.55      STOCK  2025-09-09
# 6        ACB          Ngân hàng               4.51      STOCK  2025-09-09
# 7        KDH       Bất động sản               4.11      STOCK  2025-09-09
# 8        STB          Ngân hàng               4.06      STOCK  2025-09-09
# 9        GMD  Vận tải - Kho bãi               3.97      STOCK  2025-09-09
#
#    fundId short_name
# 0      11     SSISCA
# 1      11     SSISCA
# 2      11     SSISCA
# 3      11     SSISCA
# 4      11     SSISCA
# 5      11     SSISCA
# 6      11     SSISCA
# 7      11     SSISCA
# 8      11     SSISCA
# 9      11     SSISCA

# %%
# Phân bổ theo ngành
fund.details.industry_holding('SSISCA')
# Out:
# 2025-10-07 07:44:45 - vnstock.explorer.fmarket.fund - INFO - Retrieving data for SSISCA
#                     industry  net_asset_percent short_name
# 0                  Ngân hàng              36.75     SSISCA
# 1               Bất động sản              15.56     SSISCA
# 2                     Bán lẻ               6.32     SSISCA
# 3          Vật liệu xây dựng               6.19     SSISCA
# 4          Vận tải - Kho bãi               3.97     SSISCA
# 5     Công nghệ và thông tin               3.87     SSISCA
# 6              Thiết bị điện               3.69     SSISCA
# 7           Sản xuất Phụ trợ               3.38     SSISCA
# 8                Khai khoáng               2.55     SSISCA
# 9   Sản xuất Nhựa - Hóa chất               2.52     SSISCA
# 10                  Tiện ích               2.19     SSISCA
# 11       Thực phẩm - Đồ uống               1.91     SSISCA
# 12               Chứng khoán               1.86     SSISCA
# 13                  Bán buôn               1.06     SSISCA

# %%
# Phân bổ theo tài sản
fund.details.asset_holding('SSISCA')
# Out:
# 2025-10-07 07:44:49 - vnstock.explorer.fmarket.fund - INFO - Retrieving data for SSISCA
#    asset_percent                asset_type short_name
# 0          91.82                  Cổ phiếu     SSISCA
# 1           8.18  Tiền và tương đương tiền     SSISCA

# %% [markdown]
# ### **Dữ liệu thị trường, giá cả**

# %%
# Giá vàng SJC
from vnstock.explorer.misc.gold_price import *

# %%
btmc_goldprice().tail(5)
# Out:
#                                   name karat gold_content buy_price  \
# 1   VÀNG NGUYÊN LIỆU (Vàng thị trường)   24k        999.9  13060000
# 26  VÀNG NGUYÊN LIỆU (Vàng thị trường)   24k        999.9  13030000
# 15  VÀNG NGUYÊN LIỆU (Vàng thị trường)   24k        999.9  13030000
# 55  VÀNG NGUYÊN LIỆU (Vàng thị trường)   24k        999.9  12830000
# 11  VÀNG NGUYÊN LIỆU (Vàng thị trường)   24k        999.9  13080000
#
#    sell_price world_price              time
# 1           0           0  06/10/2025 15:37
# 26          0           0  06/10/2025 11:43
# 15          0           0  06/10/2025 12:44
# 55          0           0  06/10/2025 09:00
# 11          0           0  06/10/2025 15:06

# %%
# tỉ giá ngoại tệ
from vnstock.explorer.misc.exchange_rate import *
vcb_exchange_rate(date='2025-10-07')
# Out:
#    currency_code        currency_name  buy _cash buy _transfer       sell  \
# 2            AUD    AUSTRALIAN DOLLAR  16,943.42     17,114.56  17,662.59
# 3            CAD      CANADIAN DOLLAR  18,411.77     18,597.74  19,193.26
# 4            CHF          SWISS FRANC  32,263.35     32,589.24  33,632.79
# 5            CNY         CHINESE YUAN   3,610.20      3,646.66   3,763.43
# 6            DKK         DANISH KRONE          -      4,060.95   4,216.21
# 7            EUR                 EURO  30,096.79     30,400.80  31,683.37
# 8            GBP    UK POUND STERLING  34,518.94     34,867.61  35,984.11
# 9            HKD     HONG KONG DOLLAR   3,292.72      3,325.98   3,453.14
# 10           INR         INDIAN RUPEE          -        295.49     308.21
# 11           JPY         JAPANESE YEN     169.95        171.67     180.75
# 12           KRW           KOREAN WON      16.17         17.96      19.49
# 13           KWD        KUWAITI DINAR          -     86,020.03  90,188.92
# 14           MYR    MALAYSIAN RINGGIT          -      6,192.53   6,327.22
# 15           NOK      NORWEGIAN KRONE          -      2,593.66   2,703.62
# 16           RUB        RUSSIAN RUBLE          -        305.13     337.76
# 17           SAR  SAUDI ARABIAN RIYAL          -      6,993.20   7,294.13
# 18           SEK        SWEDISH KRONA          -      2,751.15   2,867.79
# 19           SGD     SINGAPORE DOLLAR  19,878.98     20,079.78  20,764.25
# 20           THB            THAI BAHT     717.59        797.33     831.13
# 21           USD            US DOLLAR  26,153.00     26,183.00  26,403.00
#
#           date
# 2   2025-10-07
# 3   2025-10-07
# 4   2025-10-07
# 5   2025-10-07
# 6   2025-10-07
# 7   2025-10-07
# 8   2025-10-07
# 9   2025-10-07
# 10  2025-10-07
# 11  2025-10-07
# 12  2025-10-07
# 13  2025-10-07
# 14  2025-10-07
# 15  2025-10-07
# 16  2025-10-07
# 17  2025-10-07
# 18  2025-10-07
# 19  2025-10-07
# 20  2025-10-07
# 21  2025-10-07

# %%
from modules.api import stock_api

print(stock_api.get_index_detail("VN30"))
print(stock_api.get_stock_quote("VCB"))
print(stock_api.get_history_prices("VCB", days=3))
print(stock_api.format_stock_info("VCB"))
# Out:
# {'ticker': 'VN30', 'price': 1909.65, 'change': -9.32, 'percent_change': -0.49, 'open': 1929.77, 'high': 1929.77, 'low': 1901.02, 'volume': 387728577, 'timestamp': '07-10-2025 14:59:43', 'source': 'VNStock'}
# {'symbol': 'VCB', 'price': 63700.0, 'open': 64000.0, 'high': 68400.0, 'low': 59600.0, 'change': -300.0, 'percent_change': -0.47, 'volume': 4229300, 'timestamp': '07-10-2025 14:59:44', 'source': 'VNStock.Trading'}
# {'symbol': 'VCB', 'history': [{'date': '1', 'open': 62.0, 'high': 62.0, 'low': 61.4, 'close': 61.7, 'volume': 2827042, 'change': 0.05, 'pct_change': 0.08}, {'date': '2', 'open': 62.8, 'high': 64.0, 'low': 62.8, 'close': 64.0, 'volume': 7469299, 'change': 2.3, 'pct_change': 3.73}, {'date': '3', 'open': 64.1, 'high': 64.1, 'low': 63.3, 'close': 63.7, 'volume': 4229300, 'change': -0.3, 'pct_change': -0.47}], 'days': 3, 'timestamp': '07-10-2025 14:59:44', 'source': 'VNStock.Quote'}
# 📊 **VCB** — Giá hiện tại: 63,700.0 VNĐ
# • Mở cửa: 64,000.0 | Cao nhất: 68,400.0 | Thấp nhất: 59,600.0
# • Thay đổi: -300.00 (-0.47%)
# • Khối lượng: 4,229,300
# 🕒 Cập nhật: 07-10-2025 14:59:44

# %%
from modules.api.stock_api import format_stock_info, format_top_stocks, format_market_summary
print(format_stock_info("VCB"))
# print(format_top_stocks("up", 5))
# print(format_top_stocks("down", 5))
print(format_market_summary())
# Out:
# 📊 **VCB** — Giá hiện tại: 63,600.0 VNĐ
# • Mở cửa: 64,000.0 | Cao nhất: 68,400.0 | Thấp nhất: 59,600.0
# • Thay đổi: -400.00 (-0.62%)
# • Khối lượng: 1,831,700
# 🕒 Cập nhật: 07-10-2025 13:07:42
# 📊 **TỔNG QUAN THỊ TRƯỜNG VIỆT NAM**
# 📉 **VNINDEX**: 1,692.8 điểm (-2.70, -0.16%)
#
# 📊 **Top cổ phiếu tăng mạnh**
# 🔺 BTH (172247.81%)
# 🔺 TCO (11900.59%)
# 🔺 VNI (8736.93%)
#
# 📊 **Top cổ phiếu giảm mạnh**
# 🔻 PTC (-99.96%)
# 🔻 TOP (-99.67%)
# 🔻 HTP (-98.51%)
# 🕒 Cập nhật: 07-10-2025 13:06:00
